# %%
import folium
import pandas as pd
from sklearn.cluster import KMeans
from geopy.distance import geodesic

nha = [10.7565577, 106.6248006]
ds_khach = [[10.7532397, 106.6335908], [10.7551474, 106.6342982], [10.7500, 106.6200], [10.7600, 106.6400], [10.7450, 106.6250]]

m = folium.Map(location=nha, zoom_start=14)

folium.Marker(location=nha, popup="Nha t", icon=folium.Icon(color='red', icon='home')).add_to(m)

for k in ds_khach: folium.Marker(location=k, popup='Khach hang', tooltip='Khach Hang').add_to(m)

model = KMeans(n_clusters=2, random_state=42).fit(ds_khach)
ds_kho = model.cluster_centers_

for kho in ds_kho: folium.Marker(location=kho, popup="KHO TOI UU", icon=folium.Icon(color='green', icon='star')).add_to(m)

folium.Circle(location=nha, radius=1000, color='orange', fill=True, fill_opacity=0.2).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_48080d5daf0927db3cc6b86fcec50b96 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_48080d5daf0927db3cc6b86fcec50b96&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_48080d5daf0927db3cc6b86fcec50b96 = L.map(
#                 &quot;map_48080d5daf0927db3cc6b86fcec50b96&quot;,
#                 {
#                     center: [10.7565577, 106.6248006],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6784b54e6438b298f81a073b9f2c0b8b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6784b54e6438b298f81a073b9f2c0b8b.addTo(map_48080d5daf0927db3cc6b86fcec50b96);
#
#
#             var marker_26a8021ce71853a22df5bf25b2cc8d75 = L.marker(
#                 [10.7565577, 106.6248006],
#                 {
# }
#             ).addTo(map_48080d5daf0927db3cc6b86fcec50b96);
#
#
#             var icon_e123abf62b46e7b31438b875f8281788 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_f92541b9efadcea459b8f7e0c45d7c43 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_428de1ba94a373ac0256c1640eacb958 = $(`&lt;div id=&quot;html_428de1ba94a373ac0256c1640eacb958&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nha t&lt;/div&gt;`)[0];
#                 popup_f92541b9efadcea459b8f7e0c45d7c43.setContent(html_428de1ba94a373ac0256c1640eacb958);
#
#
#
#         marker_26a8021ce71853a22df5bf25b2cc8d75.bindPopup(popup_f92541b9efadcea459b8f7e0c45d7c43)
#         ;
#
#
#
#
#                 marker_26a8021ce71853a22df5bf25b2cc8d75.setIcon(icon_e123abf62b46e7b31438b875f8281788);
#
#
#             var marker_d9d6f2fccef7136edcf3da377e437ac7 = L.marker(
#                 [10.7532397, 106.6335908],
#                 {
# }
#             ).addTo(map_48080d5daf0927db3cc6b86fcec50b96);
#
#
#         var popup_af089fea1da5f5dbc5f8ae3452af01d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_651c6cec40420216b6e53c6a0e8f9d8d = $(`&lt;div id=&quot;html_651c6cec40420216b6e53c6a0e8f9d8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Khach hang&lt;/div&gt;`)[0];
#                 popup_af089fea1da5f5dbc5f8ae3452af01d7.setContent(html_651c6cec40420216b6e53c6a0e8f9d8d);
#
#
#
#         marker_d9d6f2fccef7136edcf3da377e437ac7.bindPopup(popup_af089fea1da5f5dbc5f8ae3452af01d7)
#         ;
#
#
#
#
#             marker_d9d6f2fccef7136edcf3da377e437ac7.bindTooltip(
#                 `&lt;div&gt;
#                      Khach Hang
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_7bc8b77d0c6523d8d3b09a89fbee228c = L.marker(
#                 [10.7551474, 106.6342982],
#                 {
# }
#             ).addTo(map_48080d5daf0927db3cc6b86fcec50b96);
#
#
#         var popup_08e8cb9d4118dadee435c3c18aa8b033 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6bcf7ee575f17f24ff6c8a5482ca440f = $(`&lt;div id=&quot;html_6bcf7ee575f17f24ff6c8a5482ca440f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Khach hang&lt;/div&gt;`)[0];
#                 popup_08e8cb9d4118dadee435c3c18aa8b033.setContent(html_6bcf7ee575f17f24ff6c8a5482ca440f);
#
#
#
#         marker_7bc8b77d0c6523d8d3b09a89fbee228c.bindPopup(popup_08e8cb9d4118dadee435c3c18aa8b033)
#         ;
#
#
#
#
#             marker_7bc8b77d0c6523d8d3b09a89fbee228c.bindTooltip(
#                 `&lt;div&gt;
#                      Khach Hang
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_5e32c8b050a85d87a8fd3cf4c61910b7 = L.marker(
#                 [10.75, 106.62],
#                 {
# }
#             ).addTo(map_48080d5daf0927db3cc6b86fcec50b96);
#
#
#         var popup_0991415182212a99bbbcfa422868ca91 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91c285cd516d269b375a969de8d61ce9 = $(`&lt;div id=&quot;html_91c285cd516d269b375a969de8d61ce9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Khach hang&lt;/div&gt;`)[0];
