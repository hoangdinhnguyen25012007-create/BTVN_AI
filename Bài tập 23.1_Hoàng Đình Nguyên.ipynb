# %%
from geopy.geocoders import Nominatim
geolocator=Nominatim(user_agent='geoapi')
location=geolocator.geocode('9, Ho Chi Minh City')
print(f"Ten :{location.address}")
print(f"Toa Do :{location.latitude},{location.longitude}")
# Out:
# Ten :An Dương Vương, Khu phố 77, Phường Bình Trị Đông, Thành phố Hồ Chí Minh, 73118, Việt Nam
# Toa Do :10.7565577,106.6248006

# %%
#Bài tập 23.1-Hoàng Đình Nguyên
import folium
m = folium.Map(location=[10.7830141,106.6948927], zoom_start=15)
folium.Marker([10.7830141,106.6948927], popup='UEH University Cơ sở A', icon=folium.Icon(color="red", icon='home'), tooltip='UEH').add_to(m)
folium.Marker([10.7826372,106.6959464], popup='Hồ Con Rùa', tooltip='Hồ Con Rùa').add_to(m)
folium.Marker([10.7843001,106.6906195], popup='Giáo xứ Regina Mundi', tooltip='Giao xứ').add_to(m)
folium.Marker([10.7805545,106.6943964], popup='San Khau Kich 5B', tooltip='San Khau Kich').add_to(m)
folium.Marker([10.780376,106.697086], popup='So Ngoai Vu TP.HCM', tooltip='So Ngoai Vu').add_to(m)
folium.Marker([10.782426,106.6907823], popup='Truong Trung Hoc Pho Thong Marie Curie', tooltip='THPT Marie Curie').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_add6927335d8ab1d5bfd307c6965bfdf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_add6927335d8ab1d5bfd307c6965bfdf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_add6927335d8ab1d5bfd307c6965bfdf = L.map(
#                 &quot;map_add6927335d8ab1d5bfd307c6965bfdf&quot;,
#                 {
#                     center: [10.7830141, 106.6948927],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 15,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0aa58cae39dab601cb9e568bd8f6ffb3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0aa58cae39dab601cb9e568bd8f6ffb3.addTo(map_add6927335d8ab1d5bfd307c6965bfdf);
#
#
#             var marker_73c6955ae8478569cac20571708377bf = L.marker(
#                 [10.7830141, 106.6948927],
#                 {
# }
#             ).addTo(map_add6927335d8ab1d5bfd307c6965bfdf);
#
#
#             var icon_9b77099915629ffc6bc5b0fcb0bc4abf = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;home&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_48b460253f41d5c7b666c0b1d5d125b5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df9a144bc01367823ebd0b5aa7c36051 = $(`&lt;div id=&quot;html_df9a144bc01367823ebd0b5aa7c36051&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;UEH University Cơ sở A&lt;/div&gt;`)[0];
#                 popup_48b460253f41d5c7b666c0b1d5d125b5.setContent(html_df9a144bc01367823ebd0b5aa7c36051);
#
#
#
#         marker_73c6955ae8478569cac20571708377bf.bindPopup(popup_48b460253f41d5c7b666c0b1d5d125b5)
#         ;
#
#
#
#
#             marker_73c6955ae8478569cac20571708377bf.bindTooltip(
#                 `&lt;div&gt;
#                      UEH
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#                 marker_73c6955ae8478569cac20571708377bf.setIcon(icon_9b77099915629ffc6bc5b0fcb0bc4abf);
#
#
#             var marker_7240ce72bd5c310db8061a39c30d6f09 = L.marker(
#                 [10.7826372, 106.6959464],
#                 {
# }
#             ).addTo(map_add6927335d8ab1d5bfd307c6965bfdf);
#
#
#         var popup_653ba0e8a7d2395f832514da0c19a9df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d71e4fbd94010e5d4dcf61d848ecd19 = $(`&lt;div id=&quot;html_4d71e4fbd94010e5d4dcf61d848ecd19&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hồ Con Rùa&lt;/div&gt;`)[0];
#                 popup_653ba0e8a7d2395f832514da0c19a9df.setContent(html_4d71e4fbd94010e5d4dcf61d848ecd19);
#
#
#
#         marker_7240ce72bd5c310db8061a39c30d6f09.bindPopup(popup_653ba0e8a7d2395f832514da0c19a9df)
#         ;
#
#
#
#
#             marker_7240ce72bd5c310db8061a39c30d6f09.bindTooltip(
#                 `&lt;div&gt;
#                      Hồ Con Rùa
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_bd3b1dd32906bcf5bae6d415956ea6d9 = L.marker(
#                 [10.7843001, 106.6906195],
#                 {
# }
#             ).addTo(map_add6927335d8ab1d5bfd307c6965bfdf);
#
#
#         var popup_2702fad2f0558c8abc0efe0a3e5e381c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac6232f653103839ec1f885f9769981e = $(`&lt;div id=&quot;html_ac6232f653103839ec1f885f9769981e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Giáo xứ Regina Mundi&lt;/div&gt;`)[0];
#                 popup_2702fad2f0558c8abc0efe0a3e5e381c.setContent(html_ac6232f653103839ec1f885f9769981e);
#
#
#
#         marker_bd3b1dd32906bcf5bae6d415956ea6d9.bindPopup(popup_2702fad2f0558c8abc0efe0a3e5e381c)
#         ;
#
#
#
#
#             marker_bd3b1dd32906bcf5bae6d415956ea6d9.bindTooltip(
#                 `&lt;div&gt;
#                      Giao xứ
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_750b92e2b235864561b04a2b78c055bc = L.marker(
#                 [10.7805545, 106.6943964],
#                 {
# }
#             ).addTo(map_add6927335d8ab1d5bfd307c6965bfdf);
#
#
#         var popup_839cf6c192f138e2943dfefe693e1f9f = L.popup({
#   &quot;maxWidth&quot;:
