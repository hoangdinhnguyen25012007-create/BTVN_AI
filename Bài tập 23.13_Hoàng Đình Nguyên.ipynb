# %%
import folium
m = folium.Map(location=[10.756, 106.624], zoom_start=14)
l1 = folium.FeatureGroup(name='Tram dich vu').add_to(m)
folium.Marker([10.756, 106.624]).add_to(l1)
l2 = folium.FeatureGroup(name='Vung phuc vu').add_to(m)
folium.Circle([10.756, 106.624], radius=1000, fill=True).add_to(l2)
folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c6144cbf54f904d3f20719ccf073d409 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c6144cbf54f904d3f20719ccf073d409&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c6144cbf54f904d3f20719ccf073d409 = L.map(
#                 &quot;map_c6144cbf54f904d3f20719ccf073d409&quot;,
#                 {
#                     center: [10.756, 106.624],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 14,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_59789aa0f2971a2ee9ae240c9d3bfcc3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_59789aa0f2971a2ee9ae240c9d3bfcc3.addTo(map_c6144cbf54f904d3f20719ccf073d409);
#
#
#             var feature_group_6cebfe4c091ae9bfe6262946178d6eab = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_955b3bf2f960a0dae16e42e30e9c91b0 = L.marker(
#                 [10.756, 106.624],
#                 {
# }
#             ).addTo(feature_group_6cebfe4c091ae9bfe6262946178d6eab);
#
#
#             feature_group_6cebfe4c091ae9bfe6262946178d6eab.addTo(map_c6144cbf54f904d3f20719ccf073d409);
#
#
#             var feature_group_f1b38e702b98d284fcc74e103c2e77f1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var circle_5f04b771650b38ddd767bc8aad5e9614 = L.circle(
#                 [10.756, 106.624],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(feature_group_f1b38e702b98d284fcc74e103c2e77f1);
#
#
#             feature_group_f1b38e702b98d284fcc74e103c2e77f1.addTo(map_c6144cbf54f904d3f20719ccf073d409);
#
#
#             var layer_control_33ed122e09bbbcaa35fc099dfb4a1f88_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_59789aa0f2971a2ee9ae240c9d3bfcc3,
#                 },
#                 overlays :  {
#                     &quot;Tram dich vu&quot; : feature_group_6cebfe4c091ae9bfe6262946178d6eab,
#                     &quot;Vung phuc vu&quot; : feature_group_f1b38e702b98d284fcc74e103c2e77f1,
#                 },
#             };
#             let layer_control_33ed122e09bbbcaa35fc099dfb4a1f88 = L.control.layers(
#                 layer_control_33ed122e09bbbcaa35fc099dfb4a1f88_layers.base_layers,
#                 layer_control_33ed122e09bbbcaa35fc099dfb4a1f88_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_c6144cbf54f904d3f20719ccf073d409);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
