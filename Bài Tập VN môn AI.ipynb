# %%
from geopy.geocoders import Nominatim
geolocator=Nominatim(user_agent='geoapi')
location=geolocator.geocode('9, Ho Chi Minh City')
print(f"Ten :{location.address}")
print(f"Toa Do :{location.latitude},{location.longitude}")
# Out:
# Ten :An Dương Vương, Khu phố 77, Phường Bình Trị Đông, Thành phố Hồ Chí Minh, 73118, Việt Nam
# Toa Do :10.7565577,106.6248006

# %%
#Bài tập 23.1-Hoàng Đình Nguyên
import folium
m = folium.Map(location=[10.7830141,106.6948927], zoom_start=20)
folium.Marker([10.7830141,106.6948927], popup='UEH University Cơ sở A', tooltip='UEH').add_to(m)
folium.Marker([10.7826372,106.6959464], popup='Hồ Con Rùa', tooltip='Hồ Con Rùa').add_to(m)
folium.Marker([10.7843001,106.6906195], popup='Giáo xứ Regina Mundi', tooltip='Giao xứ').add_to(m)
folium.Marker([10.7805545,106.6943964], popup='San Khau Kich 5B', tooltip='San Khau Kich').add_to(m)
folium.Marker([10.780376,106.697086], popup='So Ngoai Vu TP.HCM', tooltip='So Ngoai Vu').add_to(m)
folium.Marker([10.782426,106.6907823], popup='Truong Trung Hoc Pho Thong Marie Curie', tooltip='THPT Marie Curie').add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
from geopy.geocoders import Nominatim
geolocator=Nominatim(user_agent='geoapi')
location=geolocator.geocode('San Bong Phu Tho, Ho Chi Minh City')
print(f"Ten :{location.address}")
print(f"Toa Do :{location.latitude},{location.longitude}")
# Out:
# Ten :Sân bóng Phú Thọ, Lê Đại Hành, Khu phố 8, Phường Phú Thọ, Thành phố Hồ Chí Minh, 72415, Việt Nam
# Toa Do :10.7683838,106.6549468

# %%
# Bài tập 23.2 - Hoàng Đình Nguyên
import folium
m = folium.Map(location=[10.7565577, 106.6248006], zoom_start=13)
locations = [
    ([10.7830141,106.6948927], 'UEH University A', 'UEH A'),
    ([10.7826372,106.6959464], 'Hồ Con Rùa', 'Hồ Con Rùa'),
    ([10.7843001,106.6906195], 'Giáo xứ Regina Mundi', 'Giáo xứ'),
    ([10.7805545,106.6943964], 'Sân khấu kịch 5B', 'Kịch 5B'),
    ([10.780376,106.697086], 'Sở Ngoại Vụ TP.HCM', 'Sở Ngoại Vụ'),
    ([10.782426,106.6907823], 'THPT Marie Curie', 'Marie Curie'),
    ([10.7865044,106.6414079], '220 Âu Cơ', 'Âu Cơ'),
    ([10.7532397,106.6335908], 'Vòng xoay Phú Lâm', 'Phú Lâm'),
    ([10.7659103,106.638643], 'Công viên Đầm Sen', 'Đầm Sen'),
    ([10.7626, 106.6676], 'UEH B', 'UEH B'),
    ([10.7725235,106.6757554], 'UEH C', 'UEH C'),
    ([10.7683838,106.6549468], 'Sân bóng Phú Thọ', 'Phú Thọ')
]
for loc in locations:
    folium.Marker( location=loc[0], popup=loc[1], tooltip=loc[2]).add_to(m)
folium.Marker(
    [10.7565577,106.6248006],
    popup='Nhà của Nguyên',
    tooltip='My Home',
    icon=folium.Icon(color="red", icon="home")
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...
