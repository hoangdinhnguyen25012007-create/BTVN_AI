# %%
import folium
a=[10.7565577, 106.6248006]
m=folium.Map(location=[10.7565577, 106.6248006], zoom_start=13)
folium.Marker(location=[10.7565577, 106.6248006], tooltip='Kho hàng', icon=folium.Icon(color="red", icon="home")).add_to(m)
folium.Marker(location=[10.7536977, 106.6346337], popup='Có thể giao hàng nhanh dưới 10 phút', tooltip='Khách Hàng 1').add_to(m)
folium.Marker(location=[10.756807, 106.5879271], popup='Giao hàng trong vòng dưới 15 phút', tooltip='Khách Hàng 2').add_to(m)
folium.Marker(location=[10.842413, 106.6155024], popup='Giao hàng trong vòng 30 phút', tooltip='Khách Hàng 3').add_to(m)
folium.Marker(location=[10.8627872, 106.6109248], popup='Nằm ngoài phạm vi giao hàng', tooltip='Khách Hàng 4').add_to(m)

folium.Circle([10.7565577, 106.6248006], radius=3000, color="green", fill=True, fill_opacity=0.1).add_to(m)
folium.Circle([10.7565577, 106.6248006], radius=5000, color="orange", fill=True, fill_opacity=0.1).add_to(m)
folium.Circle([10.7565577, 106.6248006], radius=10000, color="red", fill=True, fill_opacity=0.1).add_to(m)

folium.PolyLine(locations=[a,[10.7536977, 106.6346337]], color="green", weight=2.5, opacity=1).add_to(m)
folium.PolyLine(locations=[a,[10.756807, 106.5879271]], color="orange", weight=2.5, opacity=1).add_to(m)
folium.PolyLine(locations=[a,[10.842413, 106.6155024]], color="red", weight=2.5, opacity=1).add_to(m)
folium.PolyLine(locations=[a,[10.8627872, 106.6109248]], color="black", weight=2.5, opacity=1).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...
